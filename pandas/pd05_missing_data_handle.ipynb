# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('new_weather.csv', names=['day', 'temperature', 'windspeed', 'event'], parse_dates=['day'])
# df
# type(df.day[0])
df.set_index('day', inplace=True)
df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        NaN  sunny
# 2022-02-01         24.0        NaN   rain
# 2022-05-01          NaN        8.0  sunny
# 2022-06-01         25.0        NaN   rain
# 2022-07-01          NaN        9.0    NaN
# 2022-08-01         25.0        9.0  sunny
# 2022-09-01          NaN        NaN    NaN
# 2022-10-01         28.0        NaN    NaN
# 2022-11-01         29.0        7.0   snow
# 2022-12-01          NaN        NaN   snow
# 2022-01-13          NaN        NaN   rain
# 2022-01-14         28.0        NaN   rain
# 2022-01-15         27.0        6.0   rain

# %%
new_df = df.fillna(0) # here all NaN value replace with the 0 value
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        0.0  sunny
# 2022-02-01         24.0        0.0   rain
# 2022-05-01          0.0        8.0  sunny
# 2022-06-01         25.0        0.0   rain
# 2022-07-01          0.0        9.0      0
# 2022-08-01         25.0        9.0  sunny
# 2022-09-01          0.0        0.0      0
# 2022-10-01         28.0        0.0      0
# 2022-11-01         29.0        7.0   snow
# 2022-12-01          0.0        0.0   snow
# 2022-01-13          0.0        0.0   rain
# 2022-01-14         28.0        0.0   rain
# 2022-01-15         27.0        6.0   rain

# %%
# custome column base fillna
new_df = df.fillna({
    'temperature':0,
    'windspeed': 0,
    'event': 'no event'
})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2022-01-01         30.0        0.0     sunny
# 2022-02-01         24.0        0.0      rain
# 2022-05-01          0.0        8.0     sunny
# 2022-06-01         25.0        0.0      rain
# 2022-07-01          0.0        9.0  no event
# 2022-08-01         25.0        9.0     sunny
# 2022-09-01          0.0        0.0  no event
# 2022-10-01         28.0        0.0  no event
# 2022-11-01         29.0        7.0      snow
# 2022-12-01          0.0        0.0      snow
# 2022-01-13          0.0        0.0      rain
# 2022-01-14         28.0        0.0      rain
# 2022-01-15         27.0        6.0      rain

# %%
new_df = df.fillna(method='ffill') # fill forword
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        NaN  sunny
# 2022-02-01         24.0        NaN   rain
# 2022-05-01         24.0        8.0  sunny
# 2022-06-01         25.0        8.0   rain
# 2022-07-01         25.0        9.0   rain
# 2022-08-01         25.0        9.0  sunny
# 2022-09-01         25.0        9.0  sunny
# 2022-10-01         28.0        9.0  sunny
# 2022-11-01         29.0        7.0   snow
# 2022-12-01         29.0        7.0   snow
# 2022-01-13         29.0        7.0   rain
# 2022-01-14         28.0        7.0   rain
# 2022-01-15         27.0        6.0   rain

# %%
new_df = df.fillna(method='bfill') # fill backword
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        8.0  sunny
# 2022-02-01         24.0        8.0   rain
# 2022-05-01         25.0        8.0  sunny
# 2022-06-01         25.0        9.0   rain
# 2022-07-01         25.0        9.0  sunny
# 2022-08-01         25.0        9.0  sunny
# 2022-09-01         28.0        7.0   snow
# 2022-10-01         28.0        7.0   snow
# 2022-11-01         29.0        7.0   snow
# 2022-12-01         28.0        6.0   snow
# 2022-01-13         28.0        6.0   rain
# 2022-01-14         28.0        6.0   rain
# 2022-01-15         27.0        6.0   rain

# %%
new_df = df.fillna(method='ffill', axis=1) # row base fill forword
new_df
# Out:
#            temperature windspeed  event
# day
# 2022-01-01        30.0      30.0  sunny
# 2022-02-01        24.0      24.0   rain
# 2022-05-01         NaN       8.0  sunny
# 2022-06-01        25.0      25.0   rain
# 2022-07-01         NaN       9.0    9.0
# 2022-08-01        25.0       9.0  sunny
# 2022-09-01         NaN       NaN    NaN
# 2022-10-01        28.0      28.0   28.0
# 2022-11-01        29.0       7.0   snow
# 2022-12-01         NaN       NaN   snow
# 2022-01-13         NaN       NaN   rain
# 2022-01-14        28.0      28.0   rain
# 2022-01-15        27.0       6.0   rain

# %%
new_df = df.fillna(method='bfill', axis=1) # row base fill backword
new_df
# Out:
#            temperature windspeed  event
# day
# 2022-01-01        30.0     sunny  sunny
# 2022-02-01        24.0      rain   rain
# 2022-05-01         8.0       8.0  sunny
# 2022-06-01        25.0      rain   rain
# 2022-07-01         9.0       9.0    NaN
# 2022-08-01        25.0       9.0  sunny
# 2022-09-01         NaN       NaN    NaN
# 2022-10-01        28.0       NaN    NaN
# 2022-11-01        29.0       7.0   snow
# 2022-12-01        snow      snow   snow
# 2022-01-13        rain      rain   rain
# 2022-01-14        28.0      rain   rain
# 2022-01-15        27.0       6.0   rain

# %%
new_df = df.fillna(method='ffill', limit=1) # fill forword with limit
new_dfb
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        NaN  sunny
# 2022-02-01         24.0        NaN   rain
# 2022-05-01         24.0        8.0  sunny
# 2022-06-01         25.0        8.0   rain
# 2022-07-01         25.0        9.0   rain
# 2022-08-01         25.0        9.0  sunny
# 2022-09-01         25.0        9.0  sunny
# 2022-10-01         28.0        NaN    NaN
# 2022-11-01         29.0        7.0   snow
# 2022-12-01         29.0        7.0   snow
# 2022-01-13          NaN        NaN   rain
# 2022-01-14         28.0        NaN   rain
# 2022-01-15         27.0        6.0   rain

# %%
new_df = df.interpolate()
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01    30.000000        NaN  sunny
# 2022-02-01    24.000000        NaN   rain
# 2022-05-01    24.500000   8.000000  sunny
# 2022-06-01    25.000000   8.500000   rain
# 2022-07-01    25.000000   9.000000    NaN
# 2022-08-01    25.000000   9.000000  sunny
# 2022-09-01    26.500000   8.333333    NaN
# 2022-10-01    28.000000   7.666667    NaN
# 2022-11-01    29.000000   7.000000   snow
# 2022-12-01    28.666667   6.750000   snow
# 2022-01-13    28.333333   6.500000   rain
# 2022-01-14    28.000000   6.250000   rain
# 2022-01-15    27.000000   6.000000   rain

# %%
new_df = df.interpolate(method='time')
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01    30.000000        NaN  sunny
# 2022-02-01    24.000000        NaN   rain
# 2022-05-01    24.741667   8.000000  sunny
# 2022-06-01    25.000000   8.508197   rain
# 2022-07-01    25.000000   9.000000    NaN
# 2022-08-01    25.000000   9.000000  sunny
# 2022-09-01    26.524590   8.326087    NaN
# 2022-10-01    28.000000   7.673913    NaN
# 2022-11-01    29.000000   7.000000   snow
# 2022-12-01    29.000000   7.000000   snow
# 2022-01-13    28.153846   6.000000   rain
# 2022-01-14    28.000000   6.000000   rain
# 2022-01-15    27.000000   6.000000   rain

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-08-01         25.0        9.0  sunny
# 2022-11-01         29.0        7.0   snow
# 2022-01-15         27.0        6.0   rain

# %%
new_df = df.dropna(how="all")
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        NaN  sunny
# 2022-02-01         24.0        NaN   rain
# 2022-05-01          NaN        8.0  sunny
# 2022-06-01         25.0        NaN   rain
# 2022-07-01          NaN        9.0    NaN
# 2022-08-01         25.0        9.0  sunny
# 2022-10-01         28.0        NaN    NaN
# 2022-11-01         29.0        7.0   snow
# 2022-12-01          NaN        NaN   snow
# 2022-01-13          NaN        NaN   rain
# 2022-01-14         28.0        NaN   rain
# 2022-01-15         27.0        6.0   rain

# %%
new_df = df.dropna(thresh=1)
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        NaN  sunny
# 2022-02-01         24.0        NaN   rain
# 2022-05-01          NaN        8.0  sunny
# 2022-06-01         25.0        NaN   rain
# 2022-07-01          NaN        9.0    NaN
# 2022-08-01         25.0        9.0  sunny
# 2022-10-01         28.0        NaN    NaN
# 2022-11-01         29.0        7.0   snow
# 2022-12-01          NaN        NaN   snow
# 2022-01-13          NaN        NaN   rain
# 2022-01-14         28.0        NaN   rain
# 2022-01-15         27.0        6.0   rain

# %%
# date is not counted
new_df = df.dropna(thresh=2)
new_df
# Out:
#             temperature  windspeed  event
# day
# 2022-01-01         30.0        NaN  sunny
# 2022-02-01         24.0        NaN   rain
# 2022-05-01          NaN        8.0  sunny
# 2022-06-01         25.0        NaN   rain
# 2022-08-01         25.0        9.0  sunny
# 2022-11-01         29.0        7.0   snow
# 2022-01-14         28.0        NaN   rain
# 2022-01-15         27.0        6.0   rain

# %%
dt = pd.date_range('2022-01-01','2022-01-15')
idx = pd.DatetimeIndex(dt)
df = df.reindex(idx)
df
# Out:
#             temperature  windspeed  event
# 2022-01-01         30.0        NaN  sunny
# 2022-01-02          NaN        NaN    NaN
# 2022-01-03          NaN        NaN    NaN
# 2022-01-04          NaN        NaN    NaN
# 2022-01-05          NaN        NaN    NaN
# 2022-01-06          NaN        NaN    NaN
# 2022-01-07          NaN        NaN    NaN
# 2022-01-08          NaN        NaN    NaN
# 2022-01-09          NaN        NaN    NaN
# 2022-01-10          NaN        NaN    NaN
# 2022-01-11          NaN        NaN    NaN
# 2022-01-12          NaN        NaN    NaN
# 2022-01-13          NaN        NaN   rain
# 2022-01-14         28.0        NaN   rain
# 2022-01-15         27.0        6.0   rain

# %%
dfa = pd.read_csv('new_weather.csv', names=['day', 'temperature', 'windspeed', 'event'])
dfa
# new_df = dfa.replace('-99999', np.NaN) #single data replace
# new_df = dfa.replace(['-99999','-88888', '0'], np.NaN) # it also change windspeed 0 to NaN but here 0 is valid
new_df = dfa.replace({
    'temperature': ['-99999','-88888'],
    'windspeed': ['-99999','-88888'],
    'event': ['-99999','-88888', '0']
}, np.NaN) # now its working fine
new_df
# Out:
#           day temperature windspeed  event
# 0    1/1/2022        30 F       NaN  sunny
# 1    2/1/2022          24       NaN   rain
# 4    5/1/2022         NaN     8 mph  sunny
# 5    6/1/2022          25       NaN   rain
# 6    7/1/2022         NaN     9 kmp    NaN
# 7    8/1/2022        25 F         9  sunny
# 8    9/1/2022         NaN       NaN    NaN
# 9   10/1/2022          28       NaN    NaN
# 10  11/1/2022          29         7   snow
# 11  12/1/2022         NaN       NaN   snow
# 12  13/1/2022         NaN       NaN   rain
# 13  14/1/2022          28       NaN   rain
# 14  15/1/2022          27         0   rain

# %%
new_df1 = new_df.replace('[A-Za-z]', '',  regex=True) # all the A-Z asn a-z replace with space but i didnot change event column
new_df1
# Out:
#           day temperature windspeed event
# 0    1/1/2022         30        NaN
# 1    2/1/2022          24    -99999
# 4    5/1/2022      -99999        8
# 5    6/1/2022          25    -99999
# 6    7/1/2022      -99999        9      0
# 7    8/1/2022         25          9
# 8    9/1/2022      -99999    -99999     0
# 9   10/1/2022          28    -88888     0
# 10  11/1/2022          29         7
# 11  12/1/2022      -99999    -88888
# 12  13/1/2022      -88888    -99999
# 13  14/1/2022          28    -99999
# 14  15/1/2022          27         0

# %%
new_df2 = new_df.replace({
    'temperature': '[A-Za-z]',
    'windspeed': '[A-Za-z]',
}, '',  regex=True) # all the A-Z asn a-z replace with space but i didnot change event column
new_df2
# Out:
#           day temperature windspeed event
# 0    1/1/2022         30        NaN
# 1    2/1/2022          24    -99999
# 4    5/1/2022      -99999        8
# 5    6/1/2022          25    -99999
# 6    7/1/2022      -99999        9      0
# 7    8/1/2022         25          9
# 8    9/1/2022      -99999    -99999     0
# 9   10/1/2022          28    -88888     0
# 10  11/1/2022          29         7
# 11  12/1/2022      -99999    -88888
# 12  13/1/2022      -88888    -99999
# 13  14/1/2022          28    -99999
# 14  15/1/2022          27         0

# %%
new_df = dfa.replace(['rain', 'snow','sunny'],[1,2,3])
new_df
# Out:
#           day temperature windspeed event
# 0    1/1/2022        30 F       NaN     3
# 1    2/1/2022          24    -99999     1
# 4    5/1/2022      -99999     8 mph     3
# 5    6/1/2022          25    -99999     1
# 6    7/1/2022      -99999     9 kmp     0
# 7    8/1/2022        25 F         9     3
# 8    9/1/2022      -99999    -99999     0
# 9   10/1/2022          28    -88888     0
# 10  11/1/2022          29         7     2
# 11  12/1/2022      -99999    -88888     2
# 12  13/1/2022      -88888    -99999     1
# 13  14/1/2022          28    -99999     1
# 14  15/1/2022          27         0     1
